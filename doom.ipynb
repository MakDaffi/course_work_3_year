# %% [markdown]
# ## 1. Install VizDoom

# %%
# !pip install vizdoom
# Out:
# Requirement already satisfied: vizdoom in d:\jn\lib\site-packages (1.1.13)
# Requirement already satisfied: numpy in d:\jn\lib\site-packages (from vizdoom) (1.21.4)
# WARNING: You are using pip version 21.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'd:\jn\python.exe -m pip install --upgrade pip' command.

# %%
# !git clone https://github.com/mwydmuch/ViZDoom
# Out:
# ���⥬� �� 㤠���� ���� 㪠����� ����.
# Cloning into 'ViZDoom'...
# Updating files:  79% (1620/2033)
# Updating files:  80% (1627/2033)
# Updating files:  81% (1647/2033)
# Updating files:  82% (1668/2033)
# Updating files:  83% (1688/2033)
# Updating files:  84% (1708/2033)
# Updating files:  85% (1729/2033)
# Updating files:  86% (1749/2033)
# Updating files:  87% (1769/2033)
# Updating files:  88% (1790/2033)
# Updating files:  89% (1810/2033)
# Updating files:  90% (1830/2033)
# Updating files:  91% (1851/2033)
# Updating files:  92% (1871/2033)
# Updating files:  93% (1891/2033)
# Updating files:  94% (1912/2033)
# Updating files:  95% (1932/2033)
# Updating files:  96% (1952/2033)
# Updating files:  97% (1973/2033)
# Updating files:  98% (1993/2033)
# Updating files:  99% (2013/2033)
# Updating files: 100% (2033/2033)
# Updating files: 100% (2033/2033), done.

# %% [markdown]
# # 2. Getting up Doom

# %%
# Import vizdoom for game env
from vizdoom import * 
# Import random for action sampling
import random
# Import time for sleeping
import time 
# Import numpy for identity matrix
import numpy as np

# %%
CONFIG = 'VizDoom/scenarios/deathmatch.cfg'

# %%
# Setup game
game = DoomGame()
game.load_config(CONFIG)
game.init()

# %%
# This is the set of actions we can take in the environment
actions = np.identity(20, dtype=np.uint8)

# %%
state = game.get_state()

# %%
state.game_variables
# Out:
# array([  0., 100.,   0.,   2.,  50.])

# %%
# Loop through episodes 
episodes = 10 
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),4)
        # Print rewward 
        # print('reward:', reward) 
        time.sleep(0.02)
    print('Result:', game.get_total_reward())
    time.sleep(2)
# Out:
# Result: 3.0
# Result: 4.0
# Result: 5.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-89642c7ad77e> in <module>
#      13         info = state.game_variables
#      14         # Take an action
# ---> 15         reward = game.make_action(random.choice(actions),4)
#      16         # Print rewward
#      17         # print('reward:', reward)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3. Converting it to a Gym Environment

# %%
# !pip install gym
# Out:
# Collecting gym
#   Downloading gym-0.23.1.tar.gz (626 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting importlib-metadata>=4.10.0
#   Downloading importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.18.0 in d:\jn\lib\site-packages (from gym) (1.21.4)
# Collecting cloudpickle>=1.2.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting gym-notices>=0.0.4
#   Downloading gym_notices-0.0.6-py3-none-any.whl (2.7 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (PEP 517): started
#   Building wheel for gym (PEP 517): finished with status 'done'
#   Created wheel for gym: filename=gym-0.23.1-py3-none-any.whl size=701374 sha256=3270d1726e18294232235849da3fe9a3d18a9d3a5173b1fa284b8b542693a3e8
#   Stored in directory: c:\users\dungeon master\appdata\local\pip\cache\wheels\4e\be\7e\92a54668db96883e38ce60a9249dc55de7cd6eee49e7311940
# Successfully built gym
# Installing collected packages: zipp, importlib-metadata, gym-notices, cloudpickle, gym
# Successfully installed cloudpickle-2.0.0 gym-0.23.1 gym-notices-0.0.6 importlib-metadata-4.11.3 zipp-3.8.0
# WARNING: You are using pip version 21.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'd:\jn\python.exe -m pip install --upgrade pip' command.

# %%
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces
from gym.spaces import Discrete, Box
# Import opencv
import cv2

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False, config='VizDoom/scenarios/deadly_corridor.cfg'): 
        # Inherit from Env
        super().__init__()
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config(config)
        
        # Render frame logic
        if render == False: 
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(7)
        
        # Game variables: HEALTH DAMAGE_TAKEN HITCOUNT SELECTED_WEAPON_AMMO
        self.damage_taken = 0
        self.hitcount = 0
        self.ammo = 52 ## CHANGED
        
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(7)
        movement_reward = self.game.make_action(actions[action], 4) 
        
        reward = 0 
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            
            # Reward shaping
            game_variables = self.game.get_state().game_variables
            health, damage_taken, hitcount, ammo = game_variables
            
            # Calculate reward deltas
            damage_taken_delta = -damage_taken + self.damage_taken
            self.damage_taken = damage_taken
            hitcount_delta = hitcount - self.hitcount
            self.hitcount = hitcount
            ammo_delta = ammo - self.ammo
            self.ammo = ammo
            
            reward = movement_reward + damage_taken_delta*10 + hitcount_delta*200  + ammo_delta*5 
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %%
res = env.step(5)

# %%
state = env.reset()

# %%
# !pip install stable_baselines3
# Out:
# D:\JN\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Collecting stable_baselines3
#   Downloading stable_baselines3-1.5.0-py3-none-any.whl (177 kB)
# Requirement already satisfied: cloudpickle in d:\jn\lib\site-packages (from stable_baselines3) (2.0.0)
# Collecting gym==0.21
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
# Requirement already satisfied: torch>=1.8.1 in d:\jn\lib\site-packages (from stable_baselines3) (1.9.0+cu111)
# Requirement already satisfied: numpy in d:\jn\lib\site-packages (from stable_baselines3) (1.21.4)
# Requirement already satisfied: matplotlib in d:\jn\lib\site-packages (from stable_baselines3) (3.4.2)
# Requirement already satisfied: pandas in d:\jn\lib\site-packages (from stable_baselines3) (1.3.0)
# Requirement already satisfied: typing-extensions in d:\jn\lib\site-packages (from torch>=1.8.1->stable_baselines3) (3.7.4.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\jn\lib\site-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\jn\lib\site-packages (from matplotlib->stable_baselines3) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\jn\lib\site-packages (from matplotlib->stable_baselines3) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in d:\jn\lib\site-packages (from matplotlib->stable_baselines3) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\jn\lib\site-packages (from matplotlib->stable_baselines3) (8.3.1)
# Requirement already satisfied: six in d:\jn\lib\site-packages (from cycler>=0.10->matplotlib->stable_baselines3) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in d:\jn\lib\site-packages (from pandas->stable_baselines3) (2021.1)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616822 sha256=2aa8a4ac5b785c08f7c330549adcd5aadeeeddedf3af55a8d733c47d210e9f98
#   Stored in directory: c:\users\dungeon master\appdata\local\pip\cache\wheels\b3\50\6c\0a82c1358b4da2dbd9c1bb17e0f89467db32812ab236dbf6d5
# Successfully built gym
# Installing collected packages: gym, stable-baselines3
#   Attempting uninstall: gym
#     Found existing installation: gym 0.23.1
#     Uninstalling gym-0.23.1:
#       Successfully uninstalled gym-0.23.1
# Successfully installed gym-0.21.0 stable-baselines3-1.5.0
# WARNING: You are using pip version 21.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'd:\jn\python.exe -m pip install --upgrade pip' command.

# %%
# Import Environment checker
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-7f408921b655> in <module>
# ----> 1 env_checker.check_env(env)
#
# D:\JN\lib\site-packages\stable_baselines3\common\env_checker.py in check_env(env, warn, skip_render_check)
#     281
#     282     # ============ Check the returned values ===============
# --> 283     _check_returned_values(env, observation_space, action_space)
#     284
#     285     # ==== Check the render method and the declared render modes ====
#
# D:\JN\lib\site-packages\stable_baselines3\common\env_checker.py in _check_returned_values(env, observation_space, action_space)
#     177     assert isinstance(info, dict), "The `info` returned by `step()` must be a python dictionary"
#     178
# --> 179     if isinstance(env, gym.GoalEnv):
#     180         # For a GoalEnv, the keys are checked at reset
#     181         assert reward == env.compute_reward(obs["achieved_goal"], obs["desired_goal"], info)
#
# AttributeError: module 'gym' has no attribute 'GoalEnv'

# %%
# Import os for file nav
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_corridor'
LOG_DIR = './logs/log_corridor'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# import ppo for training
from stable_baselines3 import PPO
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=8192, clip_range=.1, gamma=.95, gae_lambda=.9)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/log_corridor\PPO_7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | 25.8     |
# | time/              |          |
# |    fps             | 28       |
# |    iterations      | 1        |
# |    time_elapsed    | 283      |
# |    total_timesteps | 8192     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.4       |
# |    ep_rew_mean          | 9.27       |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 2          |
# |    time_elapsed         | 589        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.13152626 |
# |    clip_fraction        | 0.515      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.92      |
# |    explained_variance   | -7.15e-06  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 7.7e+03    |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.0309     |
# |    value_loss           | 2.69e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.1        |
# |    ep_rew_mean          | 18          |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 3           |
# |    time_elapsed         | 884         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012680862 |
# |    clip_fraction        | 0.465       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.21e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.0191      |
# |    value_loss           | 2.15e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.4       |
# |    ep_rew_mean          | 27.3       |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 4          |
# |    time_elapsed         | 1185       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01644536 |
# |    clip_fraction        | 0.463      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | 0.479      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 8.22e+03   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | 0.0125     |
# |    value_loss           | 1.79e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.8        |
# |    ep_rew_mean          | 16          |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 5           |
# |    time_elapsed         | 1483        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014239619 |
# |    clip_fraction        | 0.487       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.53e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0133      |
# |    value_loss           | 1.83e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 6           |
# |    time_elapsed         | 1782        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015526453 |
# |    clip_fraction        | 0.493       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.02e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0171      |
# |    value_loss           | 1.8e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.1        |
# |    ep_rew_mean          | 35.7        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 7           |
# |    time_elapsed         | 2068        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010926597 |
# |    clip_fraction        | 0.483       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.02e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.0124      |
# |    value_loss           | 1.52e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.6        |
# |    ep_rew_mean          | 22.8        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 8           |
# |    time_elapsed         | 2352        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013566276 |
# |    clip_fraction        | 0.444       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.06e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.011       |
# |    value_loss           | 1.41e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.9        |
# |    ep_rew_mean          | 36          |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 9           |
# |    time_elapsed         | 2635        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012028869 |
# |    clip_fraction        | 0.475       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.97e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 1.29e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.5        |
# |    ep_rew_mean          | 58.3        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 10          |
# |    time_elapsed         | 2933        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.014028917 |
# |    clip_fraction        | 0.46        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.83e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0109      |
# |    value_loss           | 1.36e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.2       |
# |    ep_rew_mean          | 51.8       |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 11         |
# |    time_elapsed         | 3233       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01107621 |
# |    clip_fraction        | 0.456      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | 0.658      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.93e+03   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.0107     |
# |    value_loss           | 1.3e+04    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.8        |
# |    ep_rew_mean          | 44.6        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 12          |
# |    time_elapsed         | 3533        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012740951 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.54e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00929     |
# |    value_loss           | 1.17e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.1        |
# |    ep_rew_mean          | 57.5        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 13          |
# |    time_elapsed         | 3826        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013634656 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.64e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00967     |
# |    value_loss           | 1.15e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.4        |
# |    ep_rew_mean          | 49.3        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 14          |
# |    time_elapsed         | 4122        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012659954 |
# |    clip_fraction        | 0.411       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.68e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.009       |
# |    value_loss           | 1.14e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.5        |
# |    ep_rew_mean          | 52.7        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 15          |
# |    time_elapsed         | 4414        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.013229109 |
# |    clip_fraction        | 0.44        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.22e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.00912     |
# |    value_loss           | 1.05e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.8        |
# |    ep_rew_mean          | 62.4        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 16          |
# |    time_elapsed         | 4713        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.014009249 |
# |    clip_fraction        | 0.421       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.91e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00804     |
# |    value_loss           | 9.75e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | 63.2        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 17          |
# |    time_elapsed         | 5010        |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.015114199 |
# |    clip_fraction        | 0.426       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.47e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0092      |
# |    value_loss           | 9.25e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29           |
# |    ep_rew_mean          | 78.9         |
# | time/                   |              |
# |    fps                  | 27           |
# |    iterations           | 18           |
# |    time_elapsed         | 5312         |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0145622045 |
# |    clip_fraction        | 0.417        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.93e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.00911      |
# |    value_loss           | 9.89e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.3        |
# |    ep_rew_mean          | 93.3        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 19          |
# |    time_elapsed         | 5614        |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.013673269 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.21e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00766     |
# |    value_loss           | 9.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.2        |
# |    ep_rew_mean          | 98.3        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 20          |
# |    time_elapsed         | 5917        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.010745597 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.69e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0092      |
# |    value_loss           | 9.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.9        |
# |    ep_rew_mean          | 93.2        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 21          |
# |    time_elapsed         | 6219        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.014397054 |
# |    clip_fraction        | 0.424       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.33e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0101      |
# |    value_loss           | 8.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29          |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 22          |
# |    time_elapsed         | 6523        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.011161383 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.6e+03     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0069      |
# |    value_loss           | 9.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.9        |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 23          |
# |    time_elapsed         | 6821        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.012849709 |
# |    clip_fraction        | 0.415       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.83e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0102      |
# |    value_loss           | 7.71e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.4        |
# |    ep_rew_mean          | 124         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 24          |
# |    time_elapsed         | 7123        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.011879043 |
# |    clip_fraction        | 0.426       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.88e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0119      |
# |    value_loss           | 8.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.7        |
# |    ep_rew_mean          | 123         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 25          |
# |    time_elapsed         | 7412        |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.014148102 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.85e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0117      |
# |    value_loss           | 7.72e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.5        |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 26          |
# |    time_elapsed         | 7699        |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.023765404 |
# |    clip_fraction        | 0.445       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2e+03       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0119      |
# |    value_loss           | 5.79e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 27          |
# |    time_elapsed         | 7978        |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.018680643 |
# |    clip_fraction        | 0.42        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.86e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0146      |
# |    value_loss           | 6.7e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.4        |
# |    ep_rew_mean          | 166         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 28          |
# |    time_elapsed         | 8264        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.021245064 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.25e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0141      |
# |    value_loss           | 5.28e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 67         |
# |    ep_rew_mean          | 168        |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 29         |
# |    time_elapsed         | 8547       |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.02326056 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.57       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 4.96e+03   |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0128     |
# |    value_loss           | 7.17e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.3        |
# |    ep_rew_mean          | 204         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 30          |
# |    time_elapsed         | 8831        |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.020912122 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.534       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.32e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0145      |
# |    value_loss           | 6.25e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 66.4       |
# |    ep_rew_mean          | 198        |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 31         |
# |    time_elapsed         | 9121       |
# |    total_timesteps      | 253952     |
# | train/                  |            |
# |    approx_kl            | 0.02549596 |
# |    clip_fraction        | 0.453      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 0.544      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.97e+03   |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0141     |
# |    value_loss           | 6.1e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.5        |
# |    ep_rew_mean          | 188         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 32          |
# |    time_elapsed         | 9407        |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.025287302 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.64e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0154      |
# |    value_loss           | 5.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.7        |
# |    ep_rew_mean          | 230         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 33          |
# |    time_elapsed         | 9694        |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.028535858 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.914      |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.04e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0144      |
# |    value_loss           | 5.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.3        |
# |    ep_rew_mean          | 223         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 34          |
# |    time_elapsed         | 9978        |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.029033326 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.8e+03     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0126      |
# |    value_loss           | 5.71e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54         |
# |    ep_rew_mean          | 239        |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 35         |
# |    time_elapsed         | 10268      |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.02927798 |
# |    clip_fraction        | 0.347      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.756     |
# |    explained_variance   | 0.393      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.5e+03    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0147     |
# |    value_loss           | 6.8e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.4        |
# |    ep_rew_mean          | 242         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 36          |
# |    time_elapsed         | 10555       |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.037801545 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.777      |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.62e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.016       |
# |    value_loss           | 8.65e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.8        |
# |    ep_rew_mean          | 267         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 37          |
# |    time_elapsed         | 10839       |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.037173413 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.489       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.44e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0157      |
# |    value_loss           | 7.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56          |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 38          |
# |    time_elapsed         | 11124       |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.036150947 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.13e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0141      |
# |    value_loss           | 6.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.5        |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 39          |
# |    time_elapsed         | 11413       |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.027087966 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.588      |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.01e+03    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 7.63e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.3        |
# |    ep_rew_mean          | 291         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 40          |
# |    time_elapsed         | 11705       |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.028532092 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.575      |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.11e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0121      |
# |    value_loss           | 8.07e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.7        |
# |    ep_rew_mean          | 301         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 41          |
# |    time_elapsed         | 11995       |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.040514104 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.25e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0159      |
# |    value_loss           | 8.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.1        |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 42          |
# |    time_elapsed         | 12286       |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.040980164 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.43e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0137      |
# |    value_loss           | 8.07e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74          |
# |    ep_rew_mean          | 371         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 43          |
# |    time_elapsed         | 12586       |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.044527084 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.44e+03    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0154      |
# |    value_loss           | 7.9e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.5       |
# |    ep_rew_mean          | 387        |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 44         |
# |    time_elapsed         | 12884      |
# |    total_timesteps      | 360448     |
# | train/                  |            |
# |    approx_kl            | 0.05856155 |
# |    clip_fraction        | 0.402      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.666     |
# |    explained_variance   | 0.448      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.42e+03   |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.0175     |
# |    value_loss           | 8.11e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.4       |
# |    ep_rew_mean          | 378        |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 45         |
# |    time_elapsed         | 13181      |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.04696305 |
# |    clip_fraction        | 0.372      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.605     |
# |    explained_variance   | 0.522      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.88e+03   |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.0151     |
# |    value_loss           | 8.46e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.9        |
# |    ep_rew_mean          | 415         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 46          |
# |    time_elapsed         | 13469       |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.049540803 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.97e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0152      |
# |    value_loss           | 7.53e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.6        |
# |    ep_rew_mean          | 465         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 47          |
# |    time_elapsed         | 13758       |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.038195707 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.506      |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.1e+03     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0134      |
# |    value_loss           | 6.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.3        |
# |    ep_rew_mean          | 433         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 48          |
# |    time_elapsed         | 14052       |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.056678668 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.498      |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.19e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0187      |
# |    value_loss           | 6.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.8        |
# |    ep_rew_mean          | 452         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 49          |
# |    time_elapsed         | 14340       |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.049188837 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.436      |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.95e+03    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.017       |
# |    value_loss           | 6.86e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.2        |
# |    ep_rew_mean          | 431         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 50          |
# |    time_elapsed         | 14638       |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.066637434 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.84e+03    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.0189      |
# |    value_loss           | 6.57e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46          |
# |    ep_rew_mean          | 407         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 51          |
# |    time_elapsed         | 14927       |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.055982627 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.24e+03    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0177      |
# |    value_loss           | 8.17e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.5       |
# |    ep_rew_mean          | 459        |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 52         |
# |    time_elapsed         | 15216      |
# |    total_timesteps      | 425984     |
# | train/                  |            |
# |    approx_kl            | 0.05473277 |
# |    clip_fraction        | 0.26       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.319     |
# |    explained_variance   | 0.765      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.72e+03   |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.0148     |
# |    value_loss           | 6.59e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.2        |
# |    ep_rew_mean          | 539         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 53          |
# |    time_elapsed         | 15507       |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# |    approx_kl            | 0.038812235 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.318      |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.1e+03     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.0119      |
# |    value_loss           | 7.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.4        |
# |    ep_rew_mean          | 522         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 54          |
# |    time_elapsed         | 15807       |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.062093064 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.356      |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2e+03       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.019       |
# |    value_loss           | 6.53e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.9        |
# |    ep_rew_mean          | 548         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 55          |
# |    time_elapsed         | 16101       |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.045776192 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.313      |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.78e+03    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.0107      |
# |    value_loss           | 6.69e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.3        |
# |    ep_rew_mean          | 609         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 56          |
# |    time_elapsed         | 16388       |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.057716355 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.281      |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.77e+03    |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.00936     |
# |    value_loss           | 6.08e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 68.6       |
# |    ep_rew_mean          | 635        |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 57         |
# |    time_elapsed         | 16683      |
# |    total_timesteps      | 466944     |
# | train/                  |            |
# |    approx_kl            | 0.06296449 |
# |    clip_fraction        | 0.296      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.346     |
# |    explained_variance   | 0.629      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.19e+03   |
# |    n_updates            | 560        |
# |    policy_gradient_loss | 0.019      |
# |    value_loss           | 7.71e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83.2       |
# |    ep_rew_mean          | 734        |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 58         |
# |    time_elapsed         | 16974      |
# |    total_timesteps      | 475136     |
# | train/                  |            |
# |    approx_kl            | 0.05644831 |
# |    clip_fraction        | 0.271      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.312     |
# |    explained_variance   | 0.638      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.21e+03   |
# |    n_updates            | 570        |
# |    policy_gradient_loss | 0.0163     |
# |    value_loss           | 6.64e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.7        |
# |    ep_rew_mean          | 786         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 59          |
# |    time_elapsed         | 17267       |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.070271164 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.301      |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.5e+03     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | 0.0151      |
# |    value_loss           | 5.85e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.1        |
# |    ep_rew_mean          | 818         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 60          |
# |    time_elapsed         | 17559       |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.056149945 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.276      |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.61e+03    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.0157      |
# |    value_loss           | 6.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.8        |
# |    ep_rew_mean          | 927         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 61          |
# |    time_elapsed         | 17852       |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.057689756 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.07e+03    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.0146      |
# |    value_loss           | 7.02e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | 981       |
# | time/                   |           |
# |    fps                  | 28        |
# |    iterations           | 62        |
# |    time_elapsed         | 18132     |
# |    total_timesteps      | 507904    |
# | train/                  |           |
# |    approx_kl            | 0.0712374 |
# |    clip_fraction        | 0.245     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -0.26     |
# |    explained_variance   | 0.651     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 1.85e+03  |
# |    n_updates            | 610       |
# |    policy_gradient_loss | 0.0163    |
# |    value_loss           | 7.06e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89         |
# |    ep_rew_mean          | 1.09e+03   |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 63         |
# |    time_elapsed         | 18420      |
# |    total_timesteps      | 516096     |
# | train/                  |            |
# |    approx_kl            | 0.08591071 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.292     |
# |    explained_variance   | 0.688      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 848        |
# |    n_updates            | 620        |
# |    policy_gradient_loss | 0.0166     |
# |    value_loss           | 6.15e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.7       |
# |    ep_rew_mean          | 1.14e+03   |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 64         |
# |    time_elapsed         | 18709      |
# |    total_timesteps      | 524288     |
# | train/                  |            |
# |    approx_kl            | 0.07568286 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.244     |
# |    explained_variance   | 0.616      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 4.03e+03   |
# |    n_updates            | 630        |
# |    policy_gradient_loss | 0.0195     |
# |    value_loss           | 7.76e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 106        |
# |    ep_rew_mean          | 1.21e+03   |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 65         |
# |    time_elapsed         | 18997      |
# |    total_timesteps      | 532480     |
# | train/                  |            |
# |    approx_kl            | 0.08085144 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.275     |
# |    explained_variance   | 0.555      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.48e+03   |
# |    n_updates            | 640        |
# |    policy_gradient_loss | 0.0176     |
# |    value_loss           | 8.24e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 101        |
# |    ep_rew_mean          | 1.27e+03   |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 66         |
# |    time_elapsed         | 19282      |
# |    total_timesteps      | 540672     |
# | train/                  |            |
# |    approx_kl            | 0.10267161 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.261     |
# |    explained_variance   | 0.548      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.42e+03   |
# |    n_updates            | 650        |
# |    policy_gradient_loss | 0.0192     |
# |    value_loss           | 8.12e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 95.1       |
# |    ep_rew_mean          | 1.17e+03   |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 67         |
# |    time_elapsed         | 19568      |
# |    total_timesteps      | 548864     |
# | train/                  |            |
# |    approx_kl            | 0.08799054 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.239     |
# |    explained_variance   | 0.506      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1e+04      |
# |    n_updates            | 660        |
# |    policy_gradient_loss | 0.0185     |
# |    value_loss           | 9.18e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | 1.23e+03    |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 68          |
# |    time_elapsed         | 19847       |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.093070894 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.232      |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.27e+03    |
# |    n_updates            | 670         |
# |    policy_gradient_loss | 0.0187      |
# |    value_loss           | 1.02e+04    |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-4f9d496705d2> in <module>
# ----> 1 model.learn(total_timesteps=1000000, callback=callback)
#
# d:\JN\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     302     ) -> "PPO":
#     303
# --> 304         return super(PPO, self).learn(
#     305             total_timesteps=total_timesteps,
#     306             callback=callback,
#
# d:\JN\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     248         while self.num_timesteps < total_timesteps:
#     249
# --> 250             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     251
#     252             if continue_training is False:
#
# d:\JN\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     176                 clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     177
# --> 178             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     179
#     180             self.num_timesteps += env.num_envs
#
# d:\JN\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# d:\JN\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py in step_wait(self)
#      93
#      94     def step_wait(self) -> VecEnvStepReturn:
# ---> 95         observations, rewards, dones, infos = self.venv.step_wait()
#      96
#      97         # Transpose the terminal observations
#
# d:\JN\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      41     def step_wait(self) -> VecEnvStepReturn:
#      42         for env_idx in range(self.num_envs):
# ---> 43             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44                 self.actions[env_idx]
#      45             )
#
# d:\JN\lib\site-packages\stable_baselines3\common\monitor.py in step(self, action)
#      88         if self.needs_reset:
#      89             raise RuntimeError("Tried to step environment that needs reset")
# ---> 90         observation, reward, done, info = self.env.step(action)
#      91         self.rewards.append(reward)
#      92         if done:
#
# <ipython-input-16-1f8aac05019d> in step(self, action)
#      32         # Specify action and take step
#      33         actions = np.identity(7)
# ---> 34         movement_reward = self.game.make_action(actions[action], 4)
#      35
#      36         reward = 0
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load('train/train_corridor/best_model_560000')

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
# Out:
# d:\JN\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
final_reward = 0
min_rew = 1e10
max_rew = -1e10
for episode in range(100): 
    obs = env.reset()
    done = False
    total_reward = 0
    st = 0
    while not done:
        st += 1
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.02)
        total_reward += reward
        print(f'Reward on step {st} in episode {episode} : {reward}')
    final_reward += total_reward
    min_rew = min(min_rew, total_reward)
    max_rew = max(max_rew, total_reward)
    print('Total Reward for episode {} is {}'.format(total_reward, episode))
    time.sleep(2)
print(f'Maximal Reward : {max_rew}')
print(f'Minimal Reward : {min_rew}')
print(f'ep_rew_mean : {final_reward / 100}')
# Out:
# Reward on step 1 in episode 0 : -845.0
# Reward on step 2 in episode 0 : 0.0
# Reward on step 3 in episode 0 : 0.0
# Reward on step 4 in episode 0 : -600.0
# Reward on step 5 in episode 0 : -15.819534301757812
# Reward on step 6 in episode 0 : 195.0
# Reward on step 7 in episode 0 : 2.256072998046875
# Reward on step 8 in episode 0 : 2.706390380859375
# Reward on step 9 in episode 0 : 1.8253936767578125
# Reward on step 10 in episode 0 : 1.2311248779296875
# Reward on step 11 in episode 0 : 0.8303070068359375
# Reward on step 12 in episode 0 : 195.5599365234375
# Reward on step 13 in episode 0 : 6.5190887451171875
# Reward on step 14 in episode 0 : 13.500152587890625
# Reward on step 15 in episode 0 : 17.78240966796875
# Reward on step 16 in episode 0 : 14.90423583984375
# Reward on step 17 in episode 0 : 10.82501220703125
# Reward on step 18 in episode 0 : 19.16339111328125
# Reward on step 19 in episode 0 : 21.146530151367188
# Reward on step 20 in episode 0 : 22.324615478515625
# Reward on step 21 in episode 0 : 23.024429321289062
# Reward on step 22 in episode 0 : 23.440185546875
# Reward on step 23 in episode 0 : 23.687057495117188
# Reward on step 24 in episode 0 : 23.833770751953125
# Reward on step 25 in episode 0 : 23.920913696289062
# Reward on step 26 in episode 0 : 20.493438720703125
# Reward on step 27 in episode 0 : 16.353622436523438
# Reward on step 28 in episode 0 : 12.5748291015625
# Reward on step 29 in episode 0 : 5.8262786865234375
# Reward on step 30 in episode 0 : 198.92982482910156
# Reward on step 31 in episode 0 : 9.54974365234375
# Reward on step 32 in episode 0 : 16.963455200195312
# Reward on step 33 in episode 0 : 16.7242431640625
# Reward on step 34 in episode 0 : 9.105728149414062
